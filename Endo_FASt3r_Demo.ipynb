# %% [markdown]
# ## **Endo-FASt3r:Endoscopic Foundation model Adaptation for Structure from motion**

# %% [markdown]
# <!-- [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mobarakol/DARES/blob/main/DARES_Demo.ipynb) -->

# %% [markdown]
# Connecting with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Download data

# %%
# !gdown 1FXSsXj2u-9BX9buZPvtLrd0FzwWnCvr6
# !unzip -q SCARED_Images_Resized.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1FXSsXj2u-9BX9buZPvtLrd0FzwWnCvr6
# From (redirected): https://drive.google.com/uc?id=1FXSsXj2u-9BX9buZPvtLrd0FzwWnCvr6&confirm=t&uuid=2fa47d3b-e9cd-4d10-b714-4ce55ca70606
# To: /content/SCARED_Images_Resized.zip
# 100% 4.53G/4.53G [01:25<00:00, 53.0MB/s]

# %% [markdown]
# Download Code and Data from the repo

# %%
# !git clone https://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@github.com/Mona-ShZeinoddin/Endo_FASt3r.git
# Out:
# Cloning into 'Endo_FASt3r'...
# remote: Enumerating objects: 371, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 371 (delta 70), reused 26 (delta 26), pack-reused 257 (from 1)
# Receiving objects: 100% (371/371), 26.13 MiB | 10.65 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %%
# %cd Endo_FASt3r
# !gdown 1trvLsQvXpsILHTZPR-FU5z6Au4YZLwRP
# !mv gt_depths.npz /content/Endo_FASt3r/splits/endovis
# Out:
# /content/Endo_FASt3r
# Downloading...
# From (original): https://drive.google.com/uc?id=1trvLsQvXpsILHTZPR-FU5z6Au4YZLwRP
# From (redirected): https://drive.google.com/uc?id=1trvLsQvXpsILHTZPR-FU5z6Au4YZLwRP&confirm=t&uuid=a8e9621a-1552-461e-85c1-793e49109b47
# To: /content/Endo_FASt3r/gt_depths.npz
# 100% 811M/811M [00:15<00:00, 52.5MB/s]

# %% [markdown]
# Download Endo-FASt3r weights

# %%
# !gdown 18OWwl7nptKwdYSGIYV-nOGwrv-aPsO6o
# !unzip -q best_weights_2025.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=18OWwl7nptKwdYSGIYV-nOGwrv-aPsO6o
# From (redirected): https://drive.google.com/uc?id=18OWwl7nptKwdYSGIYV-nOGwrv-aPsO6o&confirm=t&uuid=5c50abf3-06cf-48e8-b235-c89b1e4008f1
# To: /content/Endo_FASt3r/best_weights_2025.zip
# 100% 1.99G/1.99G [00:40<00:00, 48.7MB/s]

# %%
# !python evaluate_depth.py --data_path /content/SCARED_Images_Resized --max_depth 150.0 --eval_mono --load_weights_folder /content/Endo_FASt3r/best_weights
# Out:
# 2025-07-16 19:20:18.416278: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752693618.624058    1853 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752693618.681097    1853 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 19:20:19.122674: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# Pose for SCARED Seq 1:

# %%
# !python evaluate_pose.py --data_path /content/SCARED_Images_Resized --load_weights_folder /content/Endo_FASt3r/best_weights --scared_pose_seq 1
# Out:
# 2025-07-16 19:21:22.715279: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752693682.735423    2212 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752693682.741701    2212 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 19:21:22.762070: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# Pose for SCARED Seq 2:

# %%
# !python evaluate_pose.py --data_path /content/SCARED_Images_Resized --load_weights_folder /content/Endo_FASt3r/best_weights --scared_pose_seq 2
# Out:
# 2025-07-16 19:26:46.793777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752694006.813879    3648 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752694006.820153    3648 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 19:26:46.850889: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python visualize_pose.py --scared_pose_seq 1
# Out:
# Figure(640x480)

# %%
# !python visualize_pose.py --scared_pose_seq 2
# Out:
# Figure(640x480)

# %%
import matplotlib.pyplot as plt
from PIL import Image
tr1 = Image.open('/content/Endo_FASt3r/trajectory_pose_seq1.png')
plt.figure(121), plt.axis('OFF'),plt.imshow(tr1)

tr1 = Image.open('/content/Endo_FASt3r/trajectory_pose_seq2.png')
plt.figure(122), plt.axis('OFF'),plt.imshow(tr1)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  (np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0)),
#  <matplotlib.image.AxesImage at 0x7804f57931d0>)

# %%
# !pip -q install open3d
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.3 MB/s eta 0:00:00

# %%
# !python evaluate_3d_reconstruction.py --data_path /content/SCARED_Images_Resized --eval_mono --load_weights_folder /content/Endo_FASt3r/best_weights --visualize_depth --save_recon
# Out:
# 2025-07-16 19:36:19.238166: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752694579.275427    6050 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752694579.289149    6050 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-16 19:36:19.332088: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import open3d as o3d
import numpy as np
import plotly.graph_objects as go

print("Load a ply point cloud, print it, and render it")
ply_point_cloud = o3d.data.PLYPointCloud()
pcd = o3d.io.read_point_cloud('/content/Endo_FASt3r/splits/endovis/reconstruction/1_1_000001.ply')
points = np.asarray(pcd.points)
# print(pcd)
# print(np.asarray(pcd.points))

colors = None
if pcd.has_colors():
    colors = np.asarray(pcd.colors)
elif pcd.has_normals():
    colors = (0.5, 0.5, 0.5) + np.asarray(pcd.normals) * 0.5


fig = go.Figure(
  data=[
    go.Scatter3d(
      x=points[:,0], y=points[:,1], z=points[:,2],
      mode='markers',
      marker=dict(size=1, color=colors)
)
],
  layout=dict(
    scene=dict(
      xaxis=dict(visible=False),
      yaxis=dict(visible=False),
      zaxis=dict(visible=False)
)
)
)
fig.show()
# Out:
# Load a ply point cloud, print it, and render it
# [Open3D INFO] Downloading https://github.com/isl-org/open3d_downloads/releases/download/20220201-data/fragment.ply
# [Open3D INFO] Downloaded to /root/open3d_data/download/PLYPointCloud/fragment.ply
# [Open3D WARNING] Read PLY failed: unable to open file: /content/Endo_FASt3r/splits/endovis/reconstruction/1_1_000001.ply
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
